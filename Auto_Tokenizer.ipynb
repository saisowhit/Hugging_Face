# %%
from transformers import pipeline
import torch
from transformers import AutoTokenizer,AutoModelForSequenceClassification

classifier=pipeline("sentiment-analysis")

res=classifier("I am waiting for a long time")
print(res)
model_name="distilbert-base-uncased-finetuned-sst-2-english"

model=AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer=AutoTokenizer.from_pretrained(model_name)
classifier=pipeline("sentiment-analysis",model=model,tokenizer=tokenizer)

res=classifier("I was waiting for this to happen")
# print(res)
# from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
sequence="Using a transformer network is simple"
res=tokenizer(sequence)
tokens=tokenizer.tokenize(sequence)
ids=tokenizer.convert_to_tokens_to_ids(tokens)
decoded_string=tokenizer.decode(ids)
print(decoded_string)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'label': 'NEGATIVE', 'score': 0.9898157119750977}]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-60f861051ea5> in <cell line: 23>()
#      21 res=tokenizer(sequence)
#      22 tokens=tokenizer.tokenize(sequence)
# ---> 23 ids=tokenizer.convert_to_tokens_to_ids(tokens)
#      24 decoded_string=tokenizer.decode(ids)
#      25 print(decoded_string)
#
# AttributeError: 'BertTokenizerFast' object has no attribute 'convert_to_tokens_to_ids'
